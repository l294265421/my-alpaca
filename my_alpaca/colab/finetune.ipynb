# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/projects/my-alpaca/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-zj0qkzez
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-zj0qkzez
#   Resolved https://github.com/huggingface/peft.git to commit b21559e042555a8370f4b3cf1ad581c45291cf15
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-e5xxf14_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-e5xxf14_
#   Resolved https://github.com/huggingface/transformers.git to commit 28f26c107b4a1c5c7e32ed4d9575622da0627a40
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
import sys
project_dir = '/content/drive/MyDrive/projects/my-alpaca'
sys.path.append(project_dir)
from alpaca_lora import finetune

# %%
base_model = "decapoda-research/llama-7b-hf"
output_dir = project_dir + "model"
finetune.train(base_model=base_model, output_dir=output_dir, num_epochs=1)
# Out:
# Training Alpaca-LoRA model with params:
# base_model: decapoda-research/llama-7b-hf
# data_path: yahma/alpaca-cleaned
# output_dir: /content/drive/MyDrive/projects/my-alpacamodel
# batch_size: 128
# micro_batch_size: 8
# num_epochs: 1
# learning_rate: 0.0003
# cutoff_len: 512
# val_set_size: 2000
# lora_r: 16
# lora_alpha: 16
# lora_dropout: 0.05
# lora_target_modules: ['q_proj', 'k_proj', 'v_proj', 'o_proj']
# train_on_inputs: True
# group_by_length: False
# wandb_project:
# wandb_run_name:
# wandb_watch:
# wandb_log_model:
# resume_from_checkpoint: False
# prompt template: alpaca
# ...
